# %%
import numpy as np
import pandas as pd

# %%
country = ['India','Pakistan','USA','Nepal','Srilanka']

pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
runs = [13,24,56,78,100]

pd.Series(runs)
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']

pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks = {
    'maths':97,
    'physics':98,
     'urdu': 89,
     'english': 78
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths      97
# physics    98
# urdu       89
# english    78
# dtype: int64

# %%
marks_series = pd.Series(marks,name='nadim k marks')

# %%
marks_series
# Out:
# maths      97
# physics    98
# urdu       89
# english    78
# Name: nadim k marks, dtype: int64
